# %%
# !rm -rf glamor-research-onboarding
# !git clone --recurse-submodules https://github.com/natSegOS/glamor-research-onboarding.git
# %cd glamor-research-onboarding
# %cd experiments/000_trajectory_divergence/

# %%
# %ls
# !pip install -e .

# %%
import os
import subprocess
import sys
from google.colab import userdata

env = os.environ.copy()
try:
  env["HF_TOKEN"] = userdata.get("HF_TOKEN")
except:
  print("Make sure you added `HF_TOKEN` to your Colab Secrets!")

result = subprocess.run(
    [sys.executable, "run.py"],
    check=True,
    env=env,
)

# %%
result = subprocess.run(
    [sys.executable, "build_visualization.py"],
    check=True
)
