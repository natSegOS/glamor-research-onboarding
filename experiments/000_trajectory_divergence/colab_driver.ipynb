# %%
# !rm -rf glamor-research-onboarding
# !git clone --recurse-submodules https://github.com/natSegOS/glamor-research-onboarding.git
# %cd glamor-research-onboarding

# %%
# !pip install -e .

# %%
from huggingface_hub import login
login()

# %%
import subprocess, sys
result = subprocess.run(
    [sys.executable, "experiments/000_trajectory_divergence/run.py"],
    check=True
)

# %%
result = subprocess.run(
    [sys.executable, "experiments/000_trajectory_divergence/build_visualization.py"],
    check=True
)
