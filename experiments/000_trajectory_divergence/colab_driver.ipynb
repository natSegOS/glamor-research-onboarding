# %% [markdown]
# # GLAMOR Onboarding - Colab GPU Driver
#
# Source of truth is the GitHub repository. Colab is only used as a GPU/runtime environment.

# %% [markdown]
# ## 1. Clone Repo

# %%
# !rm -rf glamor-research-onboarding
# !git clone --recurse-submodules https://github.com/natSegOS/glamor-research-onboarding.git
# %cd glamor-research-onboarding
# Out:
# Cloning into 'glamor-research-onboarding'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 84 (delta 21), reused 67 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 82.79 KiB | 2.07 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /Users/nathansegura/Development/Personal/glamor-research-onboarding/experiments/000_trajectory_divergence/glamor-research-onboarding

# %% [markdown]
# ## 2. Install Dependencies
#
# The repo uses `pyproject.toml`; install it in editable mode so Python can import local files.

# %%
# !pip install -e .
# Out:
# total 56
# drwxr-xr-x@ 11 nathansegura  staff   352 May 20 21:52 .
# drwxr-xr-x@ 13 nathansegura  staff   416 May 21 12:54 ..
# -rw-r--r--@  1 nathansegura  staff  8196 May 14 14:54 .DS_Store
# drwxr-xr-x@ 15 nathansegura  staff   480 May 25 14:09 .git
# -rw-r--r--@  1 nathansegura  staff  4696 May 20 21:52 .gitignore
# drwxr-xr-x@  8 nathansegura  staff   256 May  1 10:56 .venv
# drwxr-xr-x@  5 nathansegura  staff   160 May 17 08:18 docs
# drwxr-xr-x@  3 nathansegura  staff    96 May 17 08:18 experiments
# drwxr-xr-x@  3 nathansegura  staff    96 May 17 08:18 paper
# -rw-r--r--@  1 nathansegura  staff   896 May 20 21:47 pyproject.toml
# -rw-r--r--@  1 nathansegura  staff  1218 May 17 08:18 README.md
# zsh:1: command not found: pip

# %% [markdown]
# ## 3. Hugging Face Login
#
# Only needed for gated models such as Meta LLama

# %%
from huggingface_hub import login

login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from huggingface_hub import login
#       2
#       3 login()
#
# ModuleNotFoundError: No module named 'huggingface_hub'

# %% [markdown]
# ## 5. Run Experiment Code
#
# For now this runs the existing trajectory-divergence helper scripts.

# %%
# !python experiments/000_trajectory_divergence/specs.py
# !python experiments/000_trajectory_divergence/build_visualization.py
